# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
from astropy.io import fits
from astropy.wcs import WCS
from astropy.utils.data import get_pkg_data_filename
from astropy.visualization import astropy_mpl_style
plt.style.use(astropy_mpl_style)

# %%
hdulist = get_pkg_data_filename('Halpha_map.fits')

# %%
hdu     = fits.open(hdulist)[0]
wcs     = WCS(hdu.header)
# Out:
# WARNING: FITSFixedWarning: PROJP1 = 0 /
# the PROJPn keyword is deprecated, use PVi_ma. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PROJP2 = 0 /
# the PROJPn keyword is deprecated, use PVi_ma. [astropy.wcs.wcs]

# %%
# h_alpha = fits.getdata(hdulist, ext=0)
# h_alpha.data.shape

# %%
fig = plt.figure(figsize=(16,8))
ax = fig.add_subplot(1,1,1, projection=wcs)
ax.imshow(hdu.data, cmap='gray', vmin=1., vmax=1000., norm=LogNorm())
ax.set_xlabel('Galactic Longitude')
ax.set_ylabel('Galactic Latitude')
ax.grid(False)
plt.savefig('h_alpha.pdf', format='pdf')
